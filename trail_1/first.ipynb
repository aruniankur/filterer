# %%
import pandas as pd

# %%
dfsc = pd.read_csv('till_18_school_program_applications_all_submitted_20260426_180811.csv')

# %%
dfsc['Section C - School Name']
# Out:
# 0                           KT Shahani Public school
# 1                                   METHODIST SCHOOL
# 2               Jawahar Navodaya Vidyalaya Papumpare
# 3      Kendriya vidyalaya CRW harnaut Nalanda bihar
# 4      Chhatrpati shahu ji maharaj university knapur
#                            ...
# 602          Kendriya vidyalaya,Ganipur Muzaffarpur
# 603           The Lovedale's Senior Secondary School
# 604           P.M. SHRI KENDRIYA VIDYALAYA, KHAGARIA
# 605              PM SHRI KENDRIYA VIDYALAYA PATRATU
# 606                      Vista International School
# Name: Section C - School Name, Length: 607, dtype: object
