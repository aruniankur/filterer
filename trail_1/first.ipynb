# %%
import pandas as pd

# %%
dfsc = pd.read_csv('after_18_school_program_applications_all_submitted_20260426_181124.csv')

# %%
dfsc['Section C - School Name']
# Out:
# 0                                        Radhika Sharma
# 1        PM SHRI KENDRIYA  VIDYALAYA NEW CANTT SHIFT 1
# 2          PM SHRI Kendriya Vidyalaya New cantt shift 1
# 3                     KENDRIYA VIDYALAYA NO. 1, SHIFT 2
# 4                 PM SHRI KENDRIYA VIDYALAYA BERHAMPUR
#                              ...
# 302            PM SHREE KENDRIYA VIDYALAYA NO. 3 SAGAR
# 303                             Kendriya vidyalaya no.3
# 304    PM shri Kendriya vidyalaya no.2 OCF Shahjahanpur
# 305           PM SHRI KENDRIYA VIDYALAYA CMERI,DURGAPUR
# 306                         PM SHRI KENDRIYA VIDYALAYA
# Name: Section C - School Name, Length: 307, dtype: object
